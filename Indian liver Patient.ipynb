# %% [markdown]
# # Indian liver Patient

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\kunal  kumar  pandey\Downloads\archive (10)\indian_liver_patient.csv")

# %%
df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
df.tail(5)
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 578   60   Male              0.5               0.1                   500
# 579   40   Male              0.6               0.1                    98
# 580   52   Male              0.8               0.2                   245
# 581   31   Male              1.3               0.5                   184
# 582   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.keys()
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
df.shape
# Out:
# (583, 11)

# %%
df.head(2)
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1

# %%
df.head(5)[["Gender","Total_Bilirubin","Direct_Bilirubin"]]
# Out:
#    Gender  Total_Bilirubin  Direct_Bilirubin
# 0  Female              0.7               0.1
# 1    Male             10.9               5.5
# 2    Male              7.3               4.1
# 3    Male              1.0               0.4
# 4    Male              3.9               2.0

# %%
df.tail()[["Age","Total_Bilirubin"]]
# Out:
#      Age  Total_Bilirubin
# 578   60              0.5
# 579   40              0.6
# 580   52              0.8
# 581   31              1.3
# 582   38              1.0

# %%
df["Alkaline_Phosphotase"].values
# Out:
# array([ 187,  699,  490,  182,  195,  208,  154,  202,  202,  290,  210,
#         260,  310,  214,  145,  183,  342,  165,  293,  293,  610,  482,
#         542,  231,  194,  289,  289,  240,  128,  188,  190,  156,  187,
#         410,  410,  482,  145,  374,  263,  275,  168,  160,  630,  415,
#         208,  275,  150,  230,  176,  206,  170,  161,  253,  198,  272,
#         272,  198,  175,  367,  145,  158,  158,  158,  208,  259,  470,
#         195,  215,  239,  215,  186,  188,  205,  171,  145,  162,  518,
#        1620,  146,  670,  915,   75,  148,  258,  237,  269,  320,  298,
#         538,  238,  214,  308,  298,  204,  168,  282,  298,  215,  265,
#         312,  161,  243,  224,  225,  170,  145,  145,  158,  158,  486,
#         188,  257,  179,  272,  661, 1580, 1630,  194,  280,  298,  300,
#         290,  188,  178,  177,  201,  802,  248, 1896,  263,  512,  237,
#         199,  238,  178, 1110,  310,  282,  282,  380,  186,  159,  332,
# ...

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      441
# Female    142
# Name: count, dtype: int64

# %%
df["Gender"].value_counts()/len(df["Gender"])
# Out:
# Gender
# Male      0.756432
# Female    0.243568
# Name: count, dtype: float64

# %%
df["Gender"].value_counts()/len(df["Gender"])*100
# Out:
# Gender
# Male      75.643225
# Female    24.356775
# Name: count, dtype: float64

# %%
df.keys()
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
df['Total_Bilirubin'].describe()
# Out:
# count    583.000000
# mean       3.298799
# std        6.209522
# min        0.400000
# 25%        0.800000
# 50%        1.000000
# 75%        2.600000
# max       75.000000
# Name: Total_Bilirubin, dtype: float64

# %%
df["Age"].tolist()
# Out:
# [65,
#  62,
#  62,
#  58,
#  72,
#  46,
#  26,
#  29,
#  17,
#  55,
#  57,
#  72,
#  64,
#  74,
#  61,
#  25,
#  38,
#  33,
#  40,
#  40,
#  51,
#  51,
#  62,
#  40,
#  63,
#  34,
#  34,
#  34,
#  20,
#  84,
#  57,
#  52,
#  57,
#  38,
#  38,
#  30,
#  17,
#  46,
#  48,
#  47,
#  45,
#  62,
#  42,
#  50,
#  85,
#  35,
#  21,
#  40,
#  32,
#  55,
#  45,
#  34,
#  38,
#  38,
#  42,
#  42,
#  33,
#  48,
#  51,
#  64,
#  31,
#  58,
#  58,
#  57,
#  57,
#  57,
#  54,
#  37,
#  66,
#  60,
#  19,
#  75,
#  75,
#  52,
#  68,
#  29,
#  31,
#  68,
#  70,
#  58,
#  58,
#  29,
#  49,
#  33,
#  32,
#  14,
#  13,
#  58,
#  18,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  75,
#  39,
#  39,
#  18,
#  18,
#  27,
#  27,
#  17,
#  55,
#  63,
#  36,
#  36,
#  36,
#  36,
#  36,
#  24,
#  48,
#  27,
#  74,
#  50,
#  50,
#  48,
#  32,
#  32,
#  32,
#  32,
#  32,
#  58,
#  64,
#  28,
#  60,
#  48,
#  64,
#  58,
#  45,
#  45,
#  70,
#  18,
#  53,
#  18,
#  66,
#  46,
#  18,
#  18,
#  15,
#  60,
#  66,
# ...

# %%
df['Age'].mean()
# Out:
# 44.74614065180103

# %%
df.Age.median()
# Out:
# 45.0

# %%
df.Alkaline_Phosphotase.max()
# Out:
# 2110

# %%
df.Alkaline_Phosphotase.min()
# Out:
# 63

# %%
df['Total_Bilirubin'].sum()
# Out:
# 1923.1999999999998

# %%
df['Total_Bilirubin'].prod()
# Out:
# 2.163950516974104e+117

# %%
df['Direct_Bilirubin'].nsmallest(3)
# Out:
# 0     0.1
# 10    0.1
# 15    0.1
# Name: Direct_Bilirubin, dtype: float64

# %%
df['Direct_Bilirubin'].nlargest(4)
# Out:
# 559    19.7
# 531    18.3
# 504    17.1
# 259    14.2
# Name: Direct_Bilirubin, dtype: float64

# %%
df.sort_values(by=['Total_Protiens'],ascending=[False])[["Age","Gender",'Total_Protiens']].head(5)
# Out:
#      Age  Gender  Total_Protiens
# 273   30    Male             9.6
# 270   37    Male             9.5
# 519   35    Male             9.2
# 510   37  Female             9.2
# 335   13  Female             8.9

# %%
df.sort_values(by=['Total_Protiens'],ascending=[True])[["Age","Gender",'Total_Protiens']].head(5)
# Out:
#      Age  Gender  Total_Protiens
# 180   75    Male             2.7
# 269   26    Male             2.8
# 181   75    Male             3.0
# 458   26    Male             3.6
# 533   46  Female             3.6

# %%
df.sort_values(by=['Total_Protiens'],ascending=[True])[["Age","Gender",'Total_Protiens']].tail(5)
# Out:
#      Age  Gender  Total_Protiens
# 335   13  Female             8.9
# 519   35    Male             9.2
# 510   37  Female             9.2
# 270   37    Male             9.5
# 273   30    Male             9.6

# %%
# relational operator
df[df["Gender"]=="Female"].head(5)
# Out:
#     Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0    65  Female              0.7               0.1                   187
# 6    26  Female              0.9               0.2                   154
# 7    29  Female              0.9               0.3                   202
# 13   74  Female              1.1               0.4                   214
# 18   40  Female              0.9               0.3                   293
#
#     Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                         16                          18             6.8
# 6                         16                          12             7.0
# 7                         14                          11             6.7
# 13                        22                          30             8.1
# 18                       232                         245             6.8
#
#     Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
df[df["Age"]>=50].head(5)
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
df["Albumin"].nsmallest(3)
# Out:
# 180    0.9
# 458    0.9
# 533    1.0
# Name: Albumin, dtype: float64

# %%
df[df["Albumin"]<=1]
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 180   75    Male              2.8               1.3                   250
# 458   26    Male              6.8               3.2                   140
# 533   46  Female              1.4               0.4                   298
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 180                        23                          29             2.7
# 458                        37                          19             3.6
# 533                       509                         623             3.6
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 180      0.9                         0.5        1
# 458      0.9                         0.3        1
# 533      1.0                         0.3        1

# %%
# logical Operator
df[(df["Age"]>=35) & (df["Total_Bilirubin"]<=6)].head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
# 5   46    Male              1.8               0.7                   208
# 9   55    Male              0.7               0.2                   290
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 3                        14                          20             6.8
# 4                        27                          59             7.3
# 5                        19                          14             7.6
# 9                        53                          58             6.8
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                         0.9        1
# ...

# %%
value=df[(df["Age"]>=35) & (df["Total_Bilirubin"]<=6)].tail()

# %%
value["Total_Bilirubin"].sum()
# Out:
# 4.0

# %%
value["Total_Bilirubin"].prod()
# Out:
# 0.264

# %%
value["Total_Bilirubin"].min()
# Out:
# 0.5

# %%
value["Total_Bilirubin"].max()
# Out:
# 1.1

# %%
df[(df["Gender"]=="Female") | (df["Age"]>=35) | (df["Total_Bilirubin"]<=6)].head(5)
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
df[(df["Gender"]=="Female") & (df["Age"]>=35) & (df["Total_Bilirubin"]<=6)].shape
# Out:
# (93, 11)

# %%
df1=df[(df["Gender"]=="Female") & (df["Age"]>=35) & (df["Total_Bilirubin"]<=6)]

# %%
df1.head()
# Out:
#     Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0    65  Female              0.7               0.1                   187
# 13   74  Female              1.1               0.4                   214
# 18   40  Female              0.9               0.3                   293
# 19   40  Female              0.9               0.3                   293
# 29   84  Female              0.7               0.2                   188
#
#     Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                         16                          18             6.8
# 13                        22                          30             8.1
# 18                       232                         245             6.8
# 19                       232                         245             6.8
# 29                        13                          21             6.0
#
#     Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
df1["Alkaline_Phosphotase"].sum()
# Out:
# 26226

# %%
df1["Total_Protiens"].median()
# Out:
# 6.7

# %%
df1["Total_Protiens"].max()
# Out:
# 9.2

# %%
df1["Total_Protiens"].min()
# Out:
# 3.6

# %%
# loc and iloc
df.loc[0:10,["Age","Gender","Total_Bilirubin","Direct_Bilirubin"]]
# Out:
#     Age  Gender  Total_Bilirubin  Direct_Bilirubin
# 0    65  Female              0.7               0.1
# 1    62    Male             10.9               5.5
# 2    62    Male              7.3               4.1
# 3    58    Male              1.0               0.4
# 4    72    Male              3.9               2.0
# 5    46    Male              1.8               0.7
# 6    26  Female              0.9               0.2
# 7    29  Female              0.9               0.3
# 8    17    Male              0.9               0.3
# 9    55    Male              0.7               0.2
# 10   57    Male              0.6               0.1

# %%
df.iloc[0:10:2,0:3]
# Out:
#    Age  Gender  Total_Bilirubin
# 0   65  Female              0.7
# 2   62    Male              7.3
# 4   72    Male              3.9
# 6   26  Female              0.9
# 8   17    Male              0.9

# %%
# single column of single row
df.iloc[5,2]
# Out:
# 1.8

# %%
df.head(6)
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
# 5   46    Male              1.8               0.7                   208
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
# ...

# %%
# all the column of specific row
df.iloc[5]
# Out:
# Age                             46
# Gender                        Male
# Total_Bilirubin                1.8
# Direct_Bilirubin               0.7
# Alkaline_Phosphotase           208
# Alamine_Aminotransferase        19
# Aspartate_Aminotransferase      14
# Total_Protiens                 7.6
# Albumin                        4.4
# Albumin_and_Globulin_Ratio     1.3
# Dataset                          1
# Name: 5, dtype: object

# %%
# multiple column and multiple row
df.iloc[[5,7],[3,4]]
# Out:
#    Direct_Bilirubin  Alkaline_Phosphotase
# 5               0.7                   208
# 7               0.3                   202

# %%
df.iloc[5:10,[5]]
# Out:
#    Alamine_Aminotransferase
# 5                        19
# 6                        16
# 7                        14
# 8                        22
# 9                        53

# %%
# using loc funcation
df.loc[5,["Alamine_Aminotransferase"]]
# Out:
# Alamine_Aminotransferase    19
# Name: 5, dtype: object

# %%
# range of row
df.loc[10:0:-1,["Alamine_Aminotransferase","Total_Bilirubin"]]
# Out:
#     Alamine_Aminotransferase  Total_Bilirubin
# 10                        51              0.6
# 9                         53              0.7
# 8                         22              0.9
# 7                         14              0.9
# 6                         16              0.9
# 5                         19              1.8
# 4                         27              3.9
# 3                         14              1.0
# 2                         60              7.3
# 1                         64             10.9
# 0                         16              0.7

# %%
# diffrent multiple row 
df.loc[[14,23,12,45],["Alamine_Aminotransferase","Total_Bilirubin"]]
# Out:
#     Alamine_Aminotransferase  Total_Bilirubin
# 14                        53              0.7
# 23                        16              1.9
# 12                        61              0.9
# 45                        48              1.8

# %%
# relational operator usnig loc fun
df.loc[df["Direct_Bilirubin"]==2,["Age","Gender","Direct_Bilirubin"]]
# Out:
#     Age Gender  Direct_Bilirubin
# 4    72   Male               2.0
# 25   34   Male               2.0
# 26   34   Male               2.0

# %%
df.loc[df["Total_Bilirubin"]<=1,["Age","Gender","Total_Bilirubin"]].head()
# Out:
#    Age  Gender  Total_Bilirubin
# 0   65  Female              0.7
# 3   58    Male              1.0
# 6   26  Female              0.9
# 7   29  Female              0.9
# 8   17    Male              0.9

# %%
df.loc[df["Age"]>80,["Age","Gender","Total_Bilirubin"]]
# Out:
#      Age  Gender  Total_Bilirubin
# 29    84  Female              0.7
# 44    85  Female              1.0
# 571   90    Male              1.1

# %%
df.loc[(df["Age"]<60) & (df["Age"]>30),["Age","Gender","Total_Bilirubin"]].head(5)
# Out:
#     Age Gender  Total_Bilirubin
# 3    58   Male              1.0
# 5    46   Male              1.8
# 9    55   Male              0.7
# 10   57   Male              0.6
# 16   38   Male              1.8

# %%
#stratwith and isna
df.loc[df['Gender'].str.startswith("Fe") & (df["Age"]>60)]
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 13    74  Female              1.1               0.4                   214
# 29    84  Female              0.7               0.2                   188
# 44    85  Female              1.0               0.3                   208
# 71    75  Female              0.8               0.2                   188
# 72    75  Female              0.8               0.2                   205
# 77    68  Female              0.6               0.1                  1620
# 123   64  Female              0.8               0.2                   178
# 131   70  Female              0.7               0.2                   237
# 141   66  Female              4.2               2.1                   159
# 146   66  Female              2.9               1.3                   168
# 208   70  Female              0.9               0.3                   220
# ...

# %%
df.loc[df['Albumin'].isin([4.2,4.3,4.4]) & (df["Age"]>60)]
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 231   61   Male              0.8               0.1                   282
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 231                        85                         231             8.5
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 231      4.3                         1.0        1

# %%
# group by funcation
df["Gender"].groupby(df["Gender"]).count()
# Out:
# Gender
# Female    142
# Male      441
# Name: Gender, dtype: int64

# %%
df["Total_Bilirubin"].groupby(df["Gender"]).sum()
# Out:
# Gender
# Female     329.8
# Male      1593.4
# Name: Total_Bilirubin, dtype: float64

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
df5=df.groupby('Gender')

# %%
df5.get_group('Male').shape
# Out:
# (441, 11)

# %%
df5.get_group('Female').shape
# Out:
# (142, 11)

# %%
df5.get_group('Female').max()
# Out:
# Age                               85
# Gender                        Female
# Total_Bilirubin                 27.7
# Direct_Bilirubin                12.8
# Alkaline_Phosphotase            1896
# Alamine_Aminotransferase         790
# Aspartate_Aminotransferase      1050
# Total_Protiens                   9.2
# Albumin                          5.5
# Albumin_and_Globulin_Ratio       1.8
# Dataset                            2
# dtype: object

# %%
df5.get_group('Female').min()
# Out:
# Age                                7
# Gender                        Female
# Total_Bilirubin                  0.5
# Direct_Bilirubin                 0.1
# Alkaline_Phosphotase              63
# Alamine_Aminotransferase          10
# Aspartate_Aminotransferase        10
# Total_Protiens                   3.6
# Albumin                          1.0
# Albumin_and_Globulin_Ratio       0.3
# Dataset                            1
# dtype: object

# %%
# aggregation funcation
df5.agg('max','min','sum','mean','describe','count')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[141], line 2
#       1 # aggregation funcation
# ----> 2 df5.agg('max','min','sum','mean','describe','count')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1445, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1442     kwargs["engine_kwargs"] = engine_kwargs
#    1444 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1445 result = op.agg()
#    1446 if not is_dict_like(func) and result is not None:
#    1447     # GH #52849
#    1448     if not self.as_index and is_list_like(func):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\apply.py:172, in Apply.agg(self)
#     169 kwargs = self.kwargs
#     171 if isinstance(func, str):
# --> 172     return self.apply_str()
#     174 if is_dict_like(func):
# ...

# %%
# aggregation funcation
df5.agg(['max','min','mean','count'])
# Out:
#        Age                      Total_Bilirubin                       \
#        max min       mean count             max  min      mean count
# Gender
# Female  85   7  43.133803   142            27.7  0.5  2.322535   142
# Male    90   4  45.265306   441            75.0  0.4  3.613152   441
#
#        Direct_Bilirubin       ...   Albumin       Albumin_and_Globulin_Ratio  \
#                     max  min  ...      mean count                        max
# Gender                        ...
# Female             12.8  0.1  ...  3.273239   142                        1.8
# Male               19.7  0.1  ...  3.099546   441                        2.8
#
#                             Dataset
#         min      mean count     max min      mean count
# Gender
# Female  0.3  0.949000   140       2   1  1.352113   142
# Male    0.3  0.946446   439       2   1  1.265306   441
#
# [2 rows x 40 columns]

# %%
df6=df5.get_group('Female')

# %%
df5['Direct_Bilirubin'].agg(['max','min'])
# Out:
#          max  min
# Gender
# Female  12.8  0.1
# Male    19.7  0.1

# %%
df.Age.unique()
# Out:
# array([65, 62, 58, 72, 46, 26, 29, 17, 55, 57, 64, 74, 61, 25, 38, 33, 40,
#        51, 63, 34, 20, 84, 52, 30, 48, 47, 45, 42, 50, 85, 35, 21, 32, 31,
#        54, 37, 66, 60, 19, 75, 68, 70, 49, 14, 13, 18, 39, 27, 36, 24, 28,
#        53, 15, 56, 44, 41,  7, 22,  8,  6,  4, 43, 23, 12, 69, 16, 78, 11,
#        73, 67, 10, 90], dtype=int64)

# %%
df5['Age'].size()
# Out:
# Gender
# Female    142
# Male      441
# Name: Age, dtype: int64

# %%
df.nlargest(5,columns='Age')
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 571   90    Male              1.1               0.3                   215
# 44    85  Female              1.0               0.3                   208
# 29    84  Female              0.7               0.2                   188
# 397   78    Male              1.0               0.3                   152
# 71    75  Female              0.8               0.2                   188
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 571                        46                         134             6.9
# 44                         17                          15             7.0
# 29                         13                          21             6.0
# 397                        28                          70             6.3
# 71                         20                          29             4.4
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
import matplotlib.pyplot as plt
x=df['Gender']
y=df['Total_Bilirubin']
plt.bar(x,y,label="indian_liver_patient",color='red')
plt.xlabel('Gender')
plt.ylabel('Total_Bilirubin')
plt.title("Gender based on Total Bilirubin")
plt.legend()
plt.show()

# %%
# scatter plot tb and td
df.plot.scatter('Total_Bilirubin','Direct_Bilirubin')
# Out:
# <Axes: xlabel='Total_Bilirubin', ylabel='Direct_Bilirubin'>

# %%
df.plot.hist(column='Albumin', by='Gender')
# Out:
# array([<Axes: title={'center': 'Female'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'Male'}, ylabel='Frequency'>], dtype=object)

# %%
x=df['Gender']
y=df['Total_Bilirubin']
plt.barh(x,y,label="indian_liver_patient",color='orange')
plt.xlabel('Gender')
plt.ylabel('Total_Bilirubin')
plt.title("Gender based on Total Bilirubin")
plt.legend()
plt.show()

# %%
x=df['Age']
y=df['Total_Bilirubin']
plt.bar(x,y,label="indian_liver_patient",color='green')
plt.xlabel('Age')
plt.ylabel('Total_Bilirubin')
plt.title("Age based on Total Bilirubin")
plt.legend()
plt.show()
