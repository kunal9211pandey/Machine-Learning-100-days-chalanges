# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r"C:\Users\kunal  kumar  pandey\Downloads\house_price.xlsx")

# %%
df
# Out:
#    area  bedrooms   age   price
# 0  2600          3   20  550000
# 1  3000          4   15  565000
# 2  3200          4   18  610000
# 3  3600          3   30  595000
# 4  4000          5    8  760000
# 5  4400          5    8  795000

# %%
df.isnull().sum()
# Out:
# area         0
# bedrooms     0
# age          0
# price        0
# dtype: int64

# %%
sns.lmplot(data=df,x='area',y='price')
plt.show()

# %%
sns.lmplot(data=df,x='age',y='price')
plt.show()

# %%
sns.lmplot(data=df,x='bedrooms ',y='price')
plt.show()

# %%
df.columns
# Out:
# Index(['area', 'bedrooms ', 'age', 'price'], dtype='object')

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(df[['area', 'bedrooms ', 'age']],df['price'])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([   142.895644  , -48591.66405516,  -8529.30115951])

# %%
reg.intercept_
# Out:
# 485561.89282339806

# %%
reg.predict([[3500,6,20]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([523560.63929803])

# %%
reg.predict([[3000,3,40]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([427301.78627387])

# %%
reg.predict([[2500,4,5]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([605787.84080221])
